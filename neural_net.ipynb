# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return (x * (1 - x))

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data[:, :2]
y = iris.target

# %%
#First and foremost, I've created the basic class to represent each nodeof the neural network arhiteture.
class NeuralNet:
    #constructor to initializw
    def __init__(self, x, y):
        self.input = x
        self.weights1 = np.random.rand(self.input.shape[1],1) #since this network consists of only one hidden layer with a single node.
        self.weights2 = np.random.rand(1,1)                 
        self.y = y.reshape(-1, 1)
        self.output = np.zeros(y.shape)
        
    #For the forward pass, I created this function.
    #All it does is calculates the weighted sum of the weights and the features and then passes it through the sigmoid function.
    def forward_pass(self):
        self.layer1 = sigmoid(np.dot(self.input, self.weights1))
        self.output = sigmoid(np.dot(self.layer1, self.weights2))
        return self.output.reshape(-1,1)
    
    def backward_pass(self):
        #Using the formula for 
#         d_weights2 = np.dot(self.layer1.T, (2*(self.y - self.output) * sigmoid_derivative(self.output)))
# #         print("np.dot(",self.layer1.T.shape,',','(2*(',self.y.shape,'-',self.output.shape,') * ',sigmoid_derivative(self.output).shape,'))')
#         d_weights1 = np.dot(self.input.T,  (np.dot(2*(self.y - self.output) * sigmoid_derivative(self.output), self.weights2.T) * sigmoid_derivative(self.layer1)))

#         # update the weights with the derivative (slope) of the loss function
#         self.weights1 += d_weights1
#         self.weights2 += d_weights2


        # lets apply log loss
        dZ = self.output - self.y
        
        loss = self.logloss(self.y, self.output).mean()
        # calc change in output loss wrto final layer
        print("loss -> ", loss)
    
    @staticmethod
    def logloss(y,y_hat):
        return -(y*np.log(y_hat) + (1-y)*np.log(1-y_hat))

# %%
network = NeuralNet(X,y)
output = network.forward_pass()
#initial output before training

# %%
#training
# for i in range(10000):
#     network.backward_pass()
# for i in range(100):
network.backward_pass()
# Out:
# loss ->  0.3358670920433344

# %%
output = network.forward_pass()
output
# Out:
# array([[0.71196177],
#        [0.71115839],
#        [0.7108537 ],
#        [0.71049033],
#        [0.71184487],
#        [0.7126778 ],
#        [0.7107895 ],
#        [0.71169883],
#        [0.7096627 ],
#        [0.71124492],
#        [0.71257241],
#        [0.71127283],
#        [0.71091688],
#        [0.7094536 ],
#        [0.71320228],
#        [0.71325307],
#        [0.7126778 ],
#        [0.71196177],
#        [0.71301009],
#        [0.71216017],
#        [0.71240457],
#        [0.71209561],
#        [0.71097754],
#        [0.71182141],
#        [0.71127283],
#        [0.71138512],
#        [0.71169883],
#        [0.71213918],
#        [0.71207411],
#        [0.7108537 ],
#        [0.71100904],
#        [0.71240457],
#        [0.71249867],
#        [0.71295067],
#        [0.71124492],
#        [0.71154569],
#        [0.7126084 ],
#        [0.71164816],
#        [0.70978391],
#        [0.71189242],
#        [0.71177272],
#        [0.70923843],
#        [0.71001801],
# ...
